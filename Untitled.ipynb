# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
grid_file = pd.read_csv('Data_for_UCI_named.csv')

# %%
grid_file.head(10)
# Out:
#        tau1      tau2      tau3      tau4        p1        p2        p3  \
# 0  2.959060  3.079885  8.381025  9.780754  3.763085 -0.782604 -1.257395
# 1  9.304097  4.902524  3.047541  1.369357  5.067812 -1.940058 -1.872742
# 2  8.971707  8.848428  3.046479  1.214518  3.405158 -1.207456 -1.277210
# 3  0.716415  7.669600  4.486641  2.340563  3.963791 -1.027473 -1.938944
# 4  3.134112  7.608772  4.943759  9.857573  3.525811 -1.125531 -1.845975
# 5  6.999209  9.109247  3.784066  4.267788  4.429669 -1.857139 -0.670397
# 6  6.710166  3.765204  6.929314  8.818562  2.397419 -0.614590 -1.208826
# 7  6.953512  1.379125  5.719400  7.870307  3.224495 -0.748998 -1.186517
# 8  4.689852  4.007747  1.478573  3.733787  4.041300 -1.410344 -1.238204
# 9  9.841496  1.413822  9.769856  7.641616  4.727595 -1.991363 -0.857637
#
#          p4        g1        g2        g3        g4      stab     stabf
# 0 -1.723086  0.650456  0.859578  0.887445  0.958034  0.055347  unstable
# ...

# %%
grid_file.describe()
# Out:
#                tau1          tau2          tau3          tau4            p1  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean       5.250000      5.250001      5.250004      5.249997      3.750000
# std        2.742548      2.742549      2.742549      2.742556      0.752160
# min        0.500793      0.500141      0.500788      0.500473      1.582590
# 25%        2.874892      2.875140      2.875522      2.874950      3.218300
# 50%        5.250004      5.249981      5.249979      5.249734      3.751025
# 75%        7.624690      7.624893      7.624948      7.624838      4.282420
# max        9.999469      9.999837      9.999450      9.999443      5.864418
#
#                  p2            p3            p4            g1            g2  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean      -1.250000     -1.250000     -1.250000      0.525000      0.525000
# ...

# %%
grid_file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   tau1    10000 non-null  float64
#  1   tau2    10000 non-null  float64
#  2   tau3    10000 non-null  float64
#  3   tau4    10000 non-null  float64
#  4   p1      10000 non-null  float64
#  5   p2      10000 non-null  float64
#  6   p3      10000 non-null  float64
#  7   p4      10000 non-null  float64
#  8   g1      10000 non-null  float64
#  9   g2      10000 non-null  float64
#  10  g3      10000 non-null  float64
#  11  g4      10000 non-null  float64
#  12  stab    10000 non-null  float64
#  13  stabf   10000 non-null  object
# dtypes: float64(13), object(1)
# memory usage: 1.1+ MB

# %%
grid_file.isnull().sum()
# Out:
# tau1     0
# tau2     0
# tau3     0
# tau4     0
# p1       0
# p2       0
# p3       0
# p4       0
# g1       0
# g2       0
# g3       0
# g4       0
# stab     0
# stabf    0
# dtype: int64

# %%
data_var = grid_file.drop(['stab', 'stabf'], axis = 1)
data_tar = grid_file['stabf']

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import ExtraTreesClassifier, RandomForestClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.model_selection import train_test_split
# Out:
# ---------------------------------------------------------------------------
# XGBoostError                              Traceback (most recent call last)
# <ipython-input-9-545dae04f87a> in <module>
#       1 from sklearn.preprocessing import StandardScaler as sc
#       2 from sklearn.ensemble import ExtraTreesClassifier, RandomForestClassifier
# ----> 3 from xgboost import XGBClassifier
#       4 from lightgbm import LGBMClassifier
#
# ~/opt/anaconda3/envs/medical/lib/python3.6/site-packages/xgboost/__init__.py in <module>
#       7 import os
#       8
# ----> 9 from .core import DMatrix, DeviceQuantileDMatrix, Booster
#      10 from .training import train, cv
#      11 from . import rabit  # noqa
#
# ~/opt/anaconda3/envs/medical/lib/python3.6/site-packages/xgboost/core.py in <module>
#     172
#     173 # load the XGBoost library globally
# --> 174 _LIB = _load_lib()
#     175
#     176
#
# ~/opt/anaconda3/envs/medical/lib/python3.6/site-packages/xgboost/core.py in _load_lib()
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(data_var, data_tar, test_size=.2, random_state=1)

# %%
ss = StandardScaler()

X_train = pd.DataFrame(sc.transform(X_train), columns=X_train.columns)

# transfoorm the test set
X_test = pd.DataFrame(sc.transform(X_test), columns=X_test.columns)

# %%
# instantiate the RandomForestClassifier with random_state of 1
forest_clf = RandomForestClassifier(random_state=1)

# Fit the classifier with training set
forest_clf.fit(X_train, y_train)

# make predictions
forest_pred = forest_clf.predict(X_test)
